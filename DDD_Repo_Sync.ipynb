# %% [markdown]
# # DDD Repo Sync (Colab)
#
# Single-cell notebook to clone or update the repo before training.

# %% [markdown]
# ## Clone or Update

# %%
REPO_URL = "https://github.com/a-n-t-h-o-n-y/DDD.git"
REPO_DIR = "/content/DDD"
BRANCH = "main"

# !test -d "{REPO_DIR}/.git" || git clone "{REPO_URL}" "{REPO_DIR}"
# !git -C "{REPO_DIR}" fetch --all --prune
# !git -C "{REPO_DIR}" checkout "{BRANCH}"
# !git -C "{REPO_DIR}" pull origin "{BRANCH}"
# !git -C "{REPO_DIR}" status -sb
